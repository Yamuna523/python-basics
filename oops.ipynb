# %% [markdown]
# # **Python OOPs Questions**

# %% [markdown]
# ```
# 1. What is Object-Oriented Programming (OOP)?
# A.  -> Instead of writing everything as functions, OOP lets you model real-world
#      entities into objects that interact with each other.
#    -> It is a programming paradigm based on the concept of objects, which can
#     OOP's contains:
#     i)Data (attributes/properties/state)
#     ii)Methods (functions/behavior/actions)
#
#
#
#    example:
#    class Car:
#     def __init__(self, brand, speed):
#         self.brand = brand     # Attribute
#         self.speed = speed
#
#     def drive(self):           # Method
#         return f"{self.brand} is driving at {self.speed} km/h"
#
#   # Object creation
#   c1 = Car("Tesla", 120)
#   print(c1.drive()) #Tesla is driving at 120 km/h
#
#
# ```
# ```
# 2.What is a class in OOP?
# A. Class is a Blue Print/ Template for creating an object
#    example:
#    we are different objects of class human being
#
#    1)class Car: #naming convention is upperCamle case
#         pass
#
#    2)class with attributes and methods
#     class Car:
#        # Constructor (initializer)
#        def __init__(self, brand, model):
#           self.brand = brand     # attribute
#           self.model = model     # attribute
#
#       # Method (behavior)
#       def drive(self):
#          return f"{self.brand} {self.model} is driving..."
#
# # Create objects (instances)
# car1 = Car("Tesla", "Model")
# car2 = Car("Toyota", "Corolla")
#
# print(car1.drive())   # Tesla Model is driving...
# print(car2.drive())   # Toyota Corolla is driving...
# ```
#
# ```
# 3.What is an object in OOP?
# A. object is an  of real-world entity created from class .If a class is a
#    blueprint, then an object is the actual product made from that blueprint.
#    Objects have:
#    1) state (attributes / data)
#    2) behavior (methods / functions)
#    3) identity (unique existence in memory)
#
#    example:
#     1) class Car:
#        pass
#
#     c1 = Car() # c1 is object here
#     c2 = Car()  #c2 is another object here
#     print(type(car1))   # <class '__main__.Car'>
#     print(id(car1))     # Unique memory identity
#
#     2) class Car:
#           def __init__(self, brand, model):
#               self.brand = brand
#               self.model = model
#
#          def drive(self):
#              return f"car brand -${self.brand} of model ${self.model}"
#
#     c1 = Car("BMW", "Model S") # car brand BMW of model Model S
#     c1 = Car("Toyoto, "Model 1") # car brand Toyoto of model Model 1
#
# ```
#
# ```
# 4.What is the difference between abstraction and encapsulation?
# A. Abstraction:
#    ->Hiding implementation details and showing only essential
#    features
#    ->Abstract class cannot be instantiated(can't make object)
#    ->It should always be a sub classed
#    ->It contains method just declared and not implemented not abstract class. subclasses are responsible for implementing this abstract method.
#
#    Analogy: When you drive a car, you use the steering wheel, pedals, and buttons, but you don’t need to know how the engine internally works.
#
#    # Abstraction can be achieved using abstract class
#    import abc #collection of multiple functions in module
#
#    example:
#       class Pwskills:
#           @abc.abstractmethod
#           def student_details(self):
#               pass
#           def student_assignment(self):
#               pass
#           def student_marks(self):
#               pass
#
#       class Student(Pwskills):
#
#           def student_details(self):
#                   print("This is student details")
#           def student_assignment(self):
#                   print("This is student assignment")
#
#       c = Student()
#       c.student_details()
#       c.student_assignment()
#
#  Encapsulation:
#   -> Wrapping data (variables) and methods (functions) into a single unit
#    (class), and controlling access to them.
#   ->the data is protected and accessed.
#   ->we can achieved encapsulation by Private variables (__variable), Getter/
#   Setter methods
#   -->access modifiers - public, private and protected
#   example:
#       class BankAccount:
#         def __init__(self, balance, account_number):
#             self.account_number = account_number   # Public
#             self._account_type = "Savings"         # Protected
#             self.__balance = balance               # Private
#
#         # Public method
#         def deposit(self, amount):
#             self.__balance += amount
#
#         # Public method (getter for private)
#         def get_balance(self):
#             return self.__balance
#
#         # Protected method (convention: for internal use only)
#         def _set_account_type(self, acc_type):
#             self._account_type = acc_type
#
#       # Create object
#       account = BankAccount(1000, "12345")
#
#       #Public: accessible directly
#       print(account.account_number)      # 12345
#
#       #Protected: can access, but not recommended
#       print(account._account_type)       # Savings
#
#       #Private: not accessible directly
#       # print(account.__balance)         # AttributeError
#
#       #Access private via method
#       account.deposit(500)
#       print(account.get_balance())       # 1500
#
#       # Access protected via method
#       account._set_account_type("Current")
#       print(account._account_type)       # Current
#
# ```
#
# ```
# 5.  What are dunder methods in Python?
# A. dunder/magic/special method defined by built-in classes in python
#    print("Hello world")  #print is a keyword/inbuilt function dunder >> d + under (duble underscore) >> all methods are double underscore is dunder method
#   * classes define these type of method for creating custom objects *implementing operator overloading()
#
#   we can use them:
#     1) To control object creation (__new__, __init__)
#     2) To provide custom behavior for operators (operator overloading, e.g. __add__, __eq__)
#     3) To give string representations (__str__, __repr__)
#     4)To make objects act like built-in types (__len__, __getitem__, __iter__)
#
#  example:
#   #__init__ >> take data with respective to object
#   class Student:
#      def __init__(self, name):
#          print(f"{name}this is executed when you make instance/object of the class")
#
#   obj1 = student() #Yamuna this is executed when you make instance/object of the class
#
#   2.another magic method before init that is  __new__
#   class Student:
#      #responsible for creating a new instance of the class
#     def __new__(cls):
#          print("This is executed even before init")
#     #to initialize the newly created instance/object
#     def __init__(self, name):
#    print(name, "this is first thing")
#
#    #This is executed before __init__ (object creation)
#    #Yamuna → This is executed in __init__ (object initialization)
# ```
# ```
# 6.Explain the concept of inheritance in OOP?
# A. Inheritance is a mechanism in Object-Oriented Programming where one class (child/derived class) can acquire properties and behaviors (attributes and methods) from another class (parent/base class).
#   Types of Inheritance
#   -> Single Inheritance → One parent, one child.
#   -> Multi-Level Inheritance → Grandparent → Parent → Child.
#   -> Multiple Inheritance → One child inherits from multiple parents.
#   -> Hierarchical Inheritance → One parent, multiple children.
#    ->Hybrid Inheritance → Combination of two or more types (Python resolves conflicts via Method resolution order(MRO)).
#
#    example:
#     class A:
#       def featureA(self): return "Feature A"
#
#     class B(A):
#         def featureB(self): return "Feature B"
#
#     class C(A):
#         def featureC(self): return "Feature C"
#
#     class D(B, C):  # Hybrid: Multiple + Multi-level
#         def featureD(self): return "Feature D"
#
#     obj = D()
#     print(obj.featureA())  # From A
#     print(obj.featureB())  # From B
#     print(obj.featureC())  # From C
#     print(obj.featureD())  # From D
#
#
# ```
#
# ```
# 7. What is polymorphism in OOP?
# A. Polymorphism here ploy means "many" and morphism is forms/sates.It allows
#    the same function/method name to behave differently depending on the context (object/class).
#
#    => their are 2 ways
#       1)method overloding
#       2)method overriding
#
#    1)method overloding:
#       => python not support this  —> the last defined method overwrites the previous ones.
#       => Instead, Python achieves a similar effect using default arguments or *args/**kwargs.
#     example:
#     class Student:
#         def student(self, name="", course=""):
#             if name and course:
#                 print(f"Welcome {name} to {course} class")
#             elif name:
#                 print(f"Welcome {name}")
#             else:
#                 print("Welcome to PW Skills")
#
#     s = Student()
#     s.student() # Welcome to PW Skills
#     s.student("Yamuna") #Welcome Yamuna
#     s.student("Yamuna", "Python") #Welcome Yamuna to Python class
#
#   2)method overriding:
#      method in parent class and child class with same signature . the child class method will be executed
#
#      example:
#      class Parent:
#         def show(self):
#           print("This is Parent class")
#
#     class Child(Parent):
#         def show(self):  # overriding parent method
#             print("This is Child class")
#
#     obj = Child()
#     obj.show() # This is Child class
# ```
#
# ```
# 8.How is encapsulation achieved in Python?
# A. Encapsulation:
#   -> Wrapping data (variables) and methods (functions) into a single unit (class), and controlling access to them.
#   ->It helps in data hiding, security, and maintainability of code.
#   ->we can achieved encapsulation by Private variables (__variable), Getter/Setter methods
#
#   -->access modifiers - public, private(noted with double underscored infront of varaible (__)) and protected(single underscore infront of variable(_))
#   example:
#     1) class Student:
#       def __init__(self, name, age):
#         self._age = age   # protected
#
#       s = Student("Yamuna", 25)
#       print(s._age)  # Possible, but not recommended
#     2)encapsulation methods example:
#     class Employee:
#         def __init__(self, name, salary):
#             self.__salary = salary  # private
#             self.name = name        # public
#
#         def set_salary(self, amount):   # setter
#             if amount > 0:
#                 self.__salary = amount
#             else:
#                 print("Invalid salary")
#
#         def get_salary(self):           # getter
#             return self.__salary
#
#     emp = Employee("Yamuna", 50000)
#     print(emp.get_salary())   # 50000
#     emp.set_salary(60000)
#     print(emp.get_salary())   # 60000
# ```
#
# ```
# 9. What is a constructor in Python?
# A. Constructor is a special method to intialize a object when it is created
#    -> Contructor in python is defined using the __init__ method
#    ->It is automatically called when new object of class is created
#    ->Its main job is to set initial values for object attributes
#    ->constructor is of 2 types -> 1) default(no arguments) 2)parameterized (accept parameters to initialize object attributes)
#
#    example:
#      class Students:
#         def __init__(self,name,age): # Constructor
#               self.name = name
#               self.age = age
#
#      s = Students("yamuna", 29)
#      s.name # yamuna
#      s.age # 29
#
# ```
#
# ```
# 10.What are class and static methods in Python?
# A. 1) class Methods:
#       -> It is declared by @classmethod decorator
#       ->first parameter of class method refers to class it self, not the instance
#       -> It can access/modify class varaibles but cannot directly access via instant variables
#
#       example:
#           class Student:
#               tutor_name = "Ajay"
#               def __init__(self, name):
#                  self.name = name
#
#               @classmethod
#               def modify_tutor_name(cls, new_name):
#                   cls.tutor_name = new_name # modifies class level data
#
#         Student.tutor_name # Ajay
#         Student.modify_tutor_name("Tushar")
#           Student.tutor_name # Tushar
#
#     2)static methods:
#         -> It is declared with the @staticmethod decorator.
#         -> Do not take self or cls as the first argument.
#         -> It behaves like a normal function inside a class, but grouped logically with the class.
#         -> Cannot access/modify class or instance variables.
#
#       example:
#         class MathUtils:
#           @staticmethod
#           def add(a, b):
#             return a + b
#
#         # Usage
#         print(MathUtils.add(10, 20))  # 30
#
#
# ```
#
# ```
# 11.What is method overloading in Python?
# A. 1)method overloding:
#       => python not support this  —> the last defined method overwrites the previous ones.
#       => Instead, Python achieves a similar effect using default arguments or *args/**kwargs.
#     example:
#     class Student:
#         def student(self, name="", course=""):
#             if name and course:
#                 print(f"Welcome {name} to {course} class")
#             elif name:
#                 print(f"Welcome {name}")
#             else:
#                 print("Welcome to PW Skills")
#
#     s = Student()
#     s.student() # Welcome to PW Skills
#     s.student("Yamuna") #Welcome Yamuna
#     s.student("Yamuna", "Python") #Welcome Yamuna to Python class
# ```
#
# ```
# 12. What is method overriding in OOP?
# A. method overriding:
#      method in parent class and child class with same signature . the child class method will be executed
#
#      example:
#      class Parent:
#         def show(self):
#           print("This is Parent class")
#
#     class Child(Parent):
#         def show(self):  # overriding parent method
#             print("This is Child class")
#
#     obj = Child()
#     obj.show() # This is Child class
# ```
#
# ```
# 13. What is a property decorator in Python?
# A. The @property decorator in Python is used to make a method act like an
#    attribute. This is part of encapsulation — we can control getting, setting, deleting values in a clean way.
#
#    example:
#       class Employee:
#         def __init__(self, name, salary):
#             self.__salary = salary
#             self.name = name
#
#         @property
#         def salary(self):            # getter
#             return self.__salary
#
#         @salary.setter
#         def salary(self, amount):    # setter
#             if amount > 0:
#                 self.__salary = amount
#             else:
#                 print("Invalid salary")
#
#     emp = Employee("Yamuna", 50000)
#
#     print(emp.salary)     # 50000
#     emp.salary = 60000    # setting value
#     print(emp.salary)     # 60000
#
# ```
#
# ```
# 14. Why is polymorphism important in OOP?
# A. Polymorphism means many forms. It allows same method name / operator to
#    behave differents based on object
#    It is important in oops because:
#    1)code reusability
#    2)Flexibility and Extendability
#    3)simplifies code
#    4)supports overloading
#       eg.
#         class Adding:
#           def add(a,b):
#               return a + b
#
#         a = Adding(2,3)
#         print(a.add()) # 5
#
#         a1 = Adding("Hello", " Yamuna")
#         print(a1.add()) # "Hello Yamuna"
# ```
#
# ```
# 15. What is an abstract class in Python?
# A. Abstract class cannot be instantiated direclty means we cannot create
#    objects from it. It act like blueprint from another class.
#    It can have abstract methods
#
#     example:
#     #to create abstract class inherit from ABC from abc(abstract base class)  module and @abstractmethod decorator for methods that must be overridden
#     from abc import ABC, abstractmethod
#
#     # Abstract class
#     class Animal(ABC):
#         @abstractmethod
#         def speak(self):
#             pass   # no implementation, only declaration
#
#     # Subclass must implement speak()
#     class Dog(Animal):
#         def speak(self):
#             return "Woof!"
#
#     class Cat(Animal):
#         def speak(self):
#             return "Meow!"
#
#     # a = Animal()  # ❌ Error: Can't instantiate abstract class
#     d = Dog()
#     c = Cat()
#
#     print(d.speak())  # Woof!
#     print(c.speak())  # Meow!
# ```
#
# ```
# 16.  What are the advantages of OOP?
# A. OOP provides advantages like modularity, encapsulation, inheritance,
#    polymorphism, abstraction, maintainability, and scalability, making code more
#    reusable, secure, flexible, and closer to real-world modeling
#
#    i)modularity: Code organized in classes and objects making ot modular
#     example: A User class can be reused in e-commerce, social media, etc.
#
#    ii)encapsulation: data hiding and security. bundle variables and methods
#       together
#       ->Access modifiers (public, protected, private) restrict direct access to sensitive data.
#       example: bank_account.balance should be private and modified only via methods
#
#     iii)inheritance: Allows a new class to inherit properties and methods of an existing class
#     example: Manager class can inherit from Employee
#
#     iv)polymorphism: improves flexibilty and extendability
#     example Animal.speak(), Dog says bow and cats says meow
#
#     v)abstraction: Hiding implementation
#
#
# ```
#
# ```
# 17. What is the difference between a class variable and an instance variable?
# A.  class variable: If modifies through the class change, the change reflects
#     for all objects
#
#     instance variable: if modifies the change effect only to that object
#
#     example:
#       class Subject:
#           subject_name = "python basics"
#
#           def __init__(self, name):
#              self.name = name
#
#       s1 = Subject("functions")
#       s2 = Subject("oops")
#
#       s1.name # functions
#       s2.name # oops
#       s1.subject_name # python basics
#       s2.subject_name # python basics
#
#
#       # Change instance variable
#       s1.name = "files"
#       print(s1.name)      # files
#       print(s2.name)      # oops only s1 changed
#
#       # Change class variable
#       Subject.company = "Python"
#       print(s1.company)   # Subject
#       print(s2.company)   # Subject ✅ affects all
# ```
#
# ```
# 18. What is multiple inheritance in Python?
# A. When a class inherits from more than one parent class, it’s called multiple
#    inheritance
#     example:
#     #multiple inheritance
#     class Father:
#         def show(self):
#             print("This is Father class")
#     class Mother:
#         def show(self):
#             print("This is Mother class")
#     class Child(Father, Mother):
#         def show(self):
#             Father.show(self)  # Call Father's show
#             Mother.show(self)  # Call Mother's show
#             print("This is Child class")
#
#     child_obj = Child()
#     child_obj.show()
#
#     #father class
#     #mother class
#     #child class
#
# ```
#
# ```
# 19. Explain the purpose of __str__ and __repr__ methods in Python?
# A. This are Dunder/magical/special methods .
#    __str__: End user redable and Friendly to read
#
#    ex:
#     class Student:
#         def __init__(self, name, age):
#             self.name = name
#             self.age = age
#
#         def __str__(self):
#             return f"Student(Name: {self.name}, Age: {self.age})"
#
#     s = Student("Yamuna", 25)
#     print(s)  # Calls __str__ → Student(Name: Yamuna, Age: 25)
#
#    __repr__: developer redable . It is unambigious
#    ex:
#    class Student:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def __repr__(self):
#         return f"Student('{self.name}', {self.age})"
#
#   s = Student("Yamuna", 25)
#   print(repr(s))  # Student('Yamuna', 25)
#
# ```
#
# ```
# 20.  What is the significance of the super() function in Python?
# A. super() is a built-in function in Python.
#    -> It gives you access to methods/attributes of a parent class (superclass) from within a child class.
#    -> Mostly used to call the parent's constructor (__init__) or methods.
#
#    ex:
#     class Person:
#     def __init__(self, name):
#         self.name = name
#         print("Person constructor called")
#
#     class Student(Person):
#         def __init__(self, name, roll_no):
#             super().__init__(name)   # Calls Person's __init__
#             self.roll_no = roll_no
#             print("Student constructor called")
#
#     s = Student("Yamuna", 101)
#
#     #Person constructor called
#     #Student constructor called
#
# ```
#
# ```
# 21. What is the significance of the __del__ method in Python?
# A. __del__ only deletes the Python object from memory. It does not delete the
#    actual file from disk.
#    1)Resource Management :- It makes sure that like files sockets and database
#    connections are released properly
#    2)Autocleanup:- When object goes out of scope or deleted using del. Python calls __del__
#    3)Helps tp prevent memory leaks:- By freeing resources they didn't need any more
#
#    ex:class FileHandler:
#           def __init__(self, filename):
#               self.file = open(filename, "w")
#               print("File opened")
#
#           def write_data(self, data):
#               self.file.write(data)
#
#           def __del__(self):
#               self.file.close()
#               print("File closed automatically when object deleted")
#
#       # Create object
#       f = FileHandler("test.txt")
#       f.write_data("Hello, Yamuna!")
#
#       # Delete object manually
#       del f
#
#       # File opened
#       # File closed automatically when object deleted
#
# ```
#
# ```
# 22. What is the difference between @staticmethod and @classmethod in Python?
# A.  @staticmethod and @classmethod both are bound to class not an instance.
#     @classmethod:
#       ->First parameter is cls(represents class itself)
#       ->It can access or modify class variables
#       ->used in class-level logic
#       ->alternative of init method to pass the data
#     example:
#         class Student:
#           def __init__(self, name):
#               self.name = name #self means this variable/method is refererring to current instance of the class
#
#           @classmethod #bound/binds to the class
#           def student_details(cls, name): #first param cls which referring to the class itself
#               return cls(name)
#
#       s= Student.student_details("Yamuna")
#       s.name # Yamuna
#
#
#
#     @staticmethod:
#       ->first parameter is none(self or cls)
#       ->It cannot access or modify class variables
#       ->this are used for utility or helper methods
#       ->it behaves like a plain function that belongs to class
#       ->works with parameter passed
#
#       ex:
#       class Calculator:
#
#         @staticmethod
#         def add(x, y):
#             return x+y
#
#         @staticmethod
#         def subtract(x,y):
#             return x-y
#
#       Calculator.add(2, 4) # 6
#       Calculator.subtract(4, 2) # 2
#
# ```
#
# ```
# 23. How does polymorphism work in Python with inheritance?
# A. ->polymorphism means many forms.
#    ->Method overriding in inheritance similarly
#    works with polymorphism.
#    ->method in parent class and child class with same signature, the child class method will be executed
#
#      example:
#      class Parent:
#         def show(self):
#           print("This is Parent class")
#
#     class Child(Parent):
#         def show(self):  # overriding parent method
#             print("This is Child class")
#
#     obj = Child()
#     obj.show() # This is Child class
# ```
#
# ```
# 24. What is method chaining in Python OOP?
# A. Method chaining means calling multiple methods on the same object in a
#   single line. This is done when each method returns the object itself (self).
#   example:
#       class Person:
#           def __init__(self, name):
#               self.name = name
#               self.age = None
#               self.city = None
#
#           def set_age(self, age):
#               self.age = age
#               return self   # return the object itself
#
#           def set_city(self, city):
#               self.city = city
#               return self   # return the object itself
#
#           def show(self):
#               print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")
#               return self   # optional, if you want to chain again
#
#       # Method chaining
#       p = Person("Yamuna").set_age(29).set_city("kakinada").show()
#       # Name: Yamuna, Age: 29, City: kakinada
#
# ```
#
# ```
# 25. What is the purpose of the __call__ method in Python?
# A. It allows an object to be called like a function.
#    If a class defines __call__, its instances behave like functions.
#
#    example:
#    class Multiplier:
#         def __init__(self, factor):
#             self.factor = factor
#
#         def __call__(self, x):
#             return x * self.factor
#
#     # create an object
#     double = Multiplier(2)
#
#     # object behaves like a function
#     print(double(5))   # 10
#     print(double(7))   # 14
#
# ```

# %% [markdown]
# # **Practical Questions**

# %%
#1 . Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

class Animal:
    def speak():
        print("generic message")

class Dog(Animal):
    def speak():
        print("Bark!")

Dog.speak()
# Out:
# Bark!

# %%
#2. . Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
      pass # abstract method has no body

class Circle(Shape):
    def __init__(self, radius):
        self.radius = 5
    def area(self,):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = 4
        self.width = 6
    def area(self):
        return self.length * self.width

c = Circle(10)
print(c.area())
r = Rectangle(10,20)
print(r.area())
# Out:
# 78.5
# 24

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
class Vehicle():
    def __init__(self, type):
        self.type = type
class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand
class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

v = Vehicle("4 wheels vehicle")
print(v.type)
c = Car("car", "black")
print(f"car type {c.type} brand {c.brand}")
e = ElectricCar("car","red","10000mah")
print(f"car type {e.type} brand {e.brand} battery {e.battery}")
# Out:
# 4 wheels vehicle
# car type car brand black
# car type car brand red battery 10000mah

# %%
#4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

#polymorphism means many forms --> The same method name (fly) behaves differently depending on the object (Bird, Sparrow, Penguin)
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow is flying")

class Penguin(Bird):
    def fly(self):
        print("Penguin is not flying")

b = Bird()
b.fly()
s = Sparrow()
s.fly()
p = Penguin()
p.fly()
#So, the same method call (fly) produces different results based on the actual object type
# Out:
# Bird is flying
# Sparrow is flying
# Penguin is not flying

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance # balance is a private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if 0 < amount < self.__balance:
            self.__balance -= amount
        else:
            print("Invalid withdrawal amount or insufficient balance")

    def check_balance(self):
      return self.__balance

account = BankAccount(5000)
# account.balance #'BankAccount' object has no attribute 'balance'
print(account.check_balance())
account.deposit(1000)
print(account.check_balance())
account.withdraw(2000)
print(account.check_balance())
# Out:
# 5000
# 6000
# 4000

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

# Runtime polymorphism in action
instruments = [Instrument(), Guitar(), Piano()]

for inst in instruments:
    inst.play()  # Same method name, different behaviors
# Out:
# Instrument is playing
# Guitar is playing
# Piano is playing

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
class MathOperations:
  counter = 0   # class variable
  # Class method: works with class, not objects
  @classmethod
  def add_numbers(cls, a, b):
      cls.counter += 1
      return a + b

  # Static method: independent, doesn’t need class or object
  @staticmethod
  def subtract_numbers(a, b):
      return a - b

# Call without creating an object
print(MathOperations.add_numbers(10, 5))   # 15
print(MathOperations.subtract_numbers(10, 5))  # 5
print(MathOperations.counter)  # 1
# Out:
# 15
# 5
# 1

# %%
#8. Implement a class Person with a class method to count the total number of persons created.
class Person():
  counter = 0 #class varaible

  def __init__(self, name):
    self.name = name
    Person.counter += 1 # increment when each time new object is created

  @classmethod
  def no_of_persons(cls): #class method
    return cls.counter

p1 = Person("yamuna")
p2 = Person("krishna")
print(Person.no_of_persons())
# Out:
# 2

# %%
#9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".
# __str__ is a special method in Python that controls what gets printed when you do print(object)
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator
  # Override the str method to display the fraction
  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

f = Fraction(10, 20)
print(f)
# Out:
# 10/20

# %%
#10.  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors
class Vector:
  def __init__(self, x, y):
    self.x = x
    self.y = y
  #overriding add method
  def __add__(self, other):
    return Vector(self.x + other.x, self.y + other.y)

#adding 2 vector data
a = Vector(1, 2)
b = Vector(3, 4)
c = a + b
print(c.x , c.y)
# Out:
# 4 6

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    return f"Hello, my name is {self.name} and I am {self.age} years old."

p = Person("Isha", 2)
print(p.greet())
# Out:
# Hello, my name is Isha and I am 2 years old.

# %%
#12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    return ({"name": self.name, 'average':sum(self.grades) / len(self.grades)})

s = Student("Yamuna", [10, 20, 30])
print(s.average_grade())
# Out:
# {'name': 'Yamuna', 'average': 20.0}

# %%
#13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area

class Rectangle:
  def __init__(self, length=0, width=0):
    self.length = length
    self.width = width

  def set_dimensions(self, length, width):
     self.length = length
     self.width = width

  def area(self):
    return self.length * self.width

m1= Rectangle()
m1.set_dimensions(10,20)
print(m1.area())
# Out:
# 200

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
  def __init__(self, hours_worked, hourly_rate):
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, hours_worked, hourly_rate, bonus):
    super().__init__(hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    return (self.hours_worked * self.hourly_rate) + self.bonus

m = Manager(10, 100, 1000)
print(m.calculate_salary())

b = Employee(10, 100)
print(b.calculate_salary())
# Out:
# 2000
# 1000

# %%
#15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

class Product:
   def __init__(self, name, price,quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

   def total_price(self):
    total_price = self.price * self.quantity
    return ({'name': self.name, 'total_price':total_price})

p = Product("pen", 10, 10)
print(p.total_price())

p = Product("cranes", 10, 15)
print(p.total_price())
# Out:
# {'name': 'pen', 'total_price': 100}
# {'name': 'cranes', 'total_price': 150}

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
from abc import ABC, abstractmethod
class Animal(ABC):  #abstract class
  @abstractmethod
  def sound(self):  #abstract method
    pass

class Cow(Animal):
  def sound(self):
    return "Moo"

class Sheep(Animal):
  def sound(self):
    return "Baa"
c1 = Cow()
print(c1.sound())
s1 = Sheep()
print(s1.sound())
# Out:
# Moo
# Baa

# %%
#17. . Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return ({"title": self.title, "author": self.author, "year_published": self.year_published})

b = Book("Yamuna Biography", "yamuna", 2025)
print(b.get_book_info())
# Out:
# {'title': 'Yamuna Biography', 'author': 'yamuna', 'year_published': 2025}

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms

class House():
  def __init__(self, address, price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

m = Mansion("kakinada", 100000, 10)
print(m.address, m.price, m.number_of_rooms)
# Out:
# kakinada 100000 10
